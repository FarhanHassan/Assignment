# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanHassan/Assignment/blob/main/Session_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import important libraries
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect("/content/drive/MyDrive/DataAnalyst/database.sqlite")
conn

# %%
q = "select * from sqlite_master"
q
# Out:
# 'select * from sqlite_master'

# %%
pd.read_sql_query(q,conn)
# Out:
#     type               name  tbl_name  rootpage  \
# 0  table           Salaries  Salaries         2
# 1  index  salaries_year_idx  Salaries     16566
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1  CREATE INDEX salaries_year_idx ON Salaries (Year)

# %%
def sql_query(q):
    return pd.read_sql_query(q, conn)

# %%
sql_query("select * from sqlite_master")
# Out:
#     type               name  tbl_name  rootpage  \
# 0  table           Salaries  Salaries         2
# 1  index  salaries_year_idx  Salaries     16566
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1  CREATE INDEX salaries_year_idx ON Salaries (Year)

# %%
sql_query("select * from sqlite_master where type = 'table'")
# Out:
#     type      name  tbl_name  rootpage  \
# 0  table  Salaries  Salaries         2
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...

# %%
q = '''select * from salaries

'''
df = sql_query(q)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ### ***1. Show The JobTitle and Overtime Pay for All Employees With Overtime Pay greater than 50000***

# %%
q = '''select jobtitle,overtimepay from salaries
        where overtimepay > 50000
        and
        overtimepay is not null
        and
        overtimepay != 'Not Provided'
'''
sql_query(q)
# Out:
#                                   JobTitle  OvertimePay
# 0          CAPTAIN III (POLICE DEPARTMENT)    245131.88
# 1          CAPTAIN III (POLICE DEPARTMENT)    106088.18
# 2     WIRE ROPE CABLE MAINTENANCE MECHANIC     56120.71
# 3       BATTALION CHIEF, (FIRE DEPARTMENT)     89062.90
# 4       BATTALION CHIEF, (FIRE DEPARTMENT)     86362.68
# ...                                    ...          ...
# 2160                      Transit Operator     51625.42
# 2161                      Transit Operator     52550.53
# 2162              Track Maintenance Worker     50265.23
# 2163             Diagnostic Imaging Tech I     74935.96
# 2164               Parking Control Officer     54738.36
#
# [2165 rows x 2 columns]

# %% [markdown]
# ## ***2. Show the Average BasePay for all Employees.***

# %%
q = 'select avg(basepay) as Avg_basepay from salaries'
sql_query(q)
# Out:
#     Avg_basepay
# 0  66385.169541

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ## ***3. Show The Top 10 highest Paid Employees***

# %%
q = 'select EmployeeName ,TotalPay from salaries order by totalpay desc limit 10'
sql_query(q)
# Out:
#            EmployeeName   TotalPay
# 0        NATHANIEL FORD  567595.43
# 1          GARY JIMENEZ  538909.28
# 2           David Shinn  471952.64
# 3            Amy P Hart  390111.98
# 4        Gary Altenberg  362844.66
# 5         John Goldberg  350403.41
# 6           Samson  Lai  347102.32
# 7       Ellen G Moffatt  344187.46
# 8  William J Coaker Jr.  339653.70
# 9        Gregory P Suhr  339282.07

# %% [markdown]
# ### ***4. Show The Average of BasePay, OverTime, OtherPay for Each Employee***

# %%
q = '''select Employeename, (basepay + overtimepay + otherpay)/3 as Avgerage from salaries
    where Employeename is not null
    and
    employeename != 'Not provided'

'''
sql_query(q)
# Out:
#              EmployeeName       Avgerage
# 0          NATHANIEL FORD  194778.849333
# 1            GARY JIMENEZ  179636.426667
# 2          ALBERT PARDINI  111759.970000
# 3       CHRISTOPHER CHONG  110781.203333
# 4         PATRICK GARDNER  108791.063333
# ...                   ...            ...
# 148645   Carolyn A Wilson       0.000000
# 148646     Joann Anderson       0.000000
# 148647        Leon Walker       0.000000
# 148648      Roy I Tillery       0.000000
# 148649          Joe Lopez    -206.043333
#
# [148650 rows x 2 columns]

# %% [markdown]
# ### ***5. Show All Employees Who Have The Word "Manager" In Their Job Title***

# %%
q = '''select employeename,jobtitle from salaries where jobtitle like '%manager%'
'''
sql_query(q)
# Out:
#               EmployeeName                                        JobTitle
# 0           NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1           EDWARD REISKIN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2              KEVIN BARRY                                     MANAGER VII
# 3             MIVIC HIROSE                                    MANAGER VIII
# 4            JULIE LABONTE                                    MANAGER VIII
# ...                    ...                                             ...
# 4105  Steven D Koneffklatt                                     Manager III
# 4106    Alice B Villagomez                                      Manager IV
# 4107    Stephen C Laplante                                      Manager II
# 4108      Shirley M Parker                           Real Property Manager
# 4109         James P Horan                                      Manager IV
#
# [4110 rows x 2 columns]

# %% [markdown]
# ### ***6. Show All Employees With A Job Title Not Equal to "Manager"***

# %%
q = '''select employeename,jobtitle from salaries where jobtitle not like '%manager%'
        and jobtitle != 'Not provided'
'''
sql_query(q)
# Out:
#              EmployeeName                                      JobTitle
# 0            GARY JIMENEZ               CAPTAIN III (POLICE DEPARTMENT)
# 1          ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# 2       CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3         PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4          DAVID SULLIVAN                     ASSISTANT DEPUTY CHIEF II
# ...                   ...                                           ...
# 144535   Carolyn A Wilson                     Human Services Technician
# 144536     Joann Anderson                   Communications Dispatcher 2
# 144537        Leon Walker                                     Custodian
# 144538      Roy I Tillery                                     Custodian
# 144539          Joe Lopez                    Counselor, Log Cabin Ranch
#
# [144540 rows x 2 columns]

# %% [markdown]
# ### ***7. Show All Employess With A Total Pay Between 50,000 and 75,000***

# %%
df.head(1)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#       BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  184152.298           0  400184.25           567595.43         567595.43
#
#    Year Notes         Agency Status
# 0  2011        San Francisco

# %%
q="select EmployeeName,TotalPay from salaries where TotalPay between 50000 and 75000"
sql_query(q)
# Out:
#              EmployeeName  TotalPay
# 0         MAMIKO NAKAMURA  74999.62
# 1           HEDLEY PRINCE  74998.73
# 2           LINDA BARNARD  74998.30
# 3        ANGELA WHITTAKER  74997.84
# 4                JANE CHU  74997.81
# ...                   ...       ...
# 33552     Stephanie Reidy  51785.23
# 33553  Maria Theresa Luna  52266.82
# 33554      Paul E Maltzer  51673.98
# 33555       Kevin I Dolar  50953.19
# 33556   Kathleen N Yumang  50348.91
#
# [33557 rows x 2 columns]

# %% [markdown]
# ### ***8. Show All Employees With A BasePay less than 50,000 Or A TotalPay Greater Than 100,000***

# %%
q="select EmployeeName,BasePay,TotalPay from salaries where BasePay < 50000 or TotalPay > 100000 "
sql_query(q)
# Out:
#             EmployeeName     BasePay   TotalPay
# 0         NATHANIEL FORD  184152.298  567595.43
# 1           GARY JIMENEZ   155966.02  538909.28
# 2         ALBERT PARDINI   212739.13  335279.91
# 3      CHRISTOPHER CHONG       77916  332343.61
# 4        PATRICK GARDNER    134401.6  326373.19
# ...                  ...         ...        ...
# 91263   Carolyn A Wilson           0       0.00
# 91264     Joann Anderson           0       0.00
# 91265        Leon Walker           0       0.00
# 91266      Roy I Tillery           0       0.00
# 91267          Joe Lopez           0    -618.13
#
# [91268 rows x 3 columns]

# %% [markdown]
# ### ***9. Show All Employees With A TotalPay Benefits Value Between 125,000 and 150,000 And A Job Title Containing Word 'Director'***

# %%
q="select * from Salaries where TotalPayBenefits between 125000 and 150000 and JobTitle like '%Director%'"
sql_query(q)
# Out:
#         Id         EmployeeName  \
# 0     2406          ANA ALVAREZ
# 1     2495        ELAINE FORBES
# 2     2670        ALLISON MAGEE
# 3     2672       NOELLE SIMMONS
# 4     2977       DONALD ELLISON
# 5     3232         MARTIN TARAS
# 6     3272         KELLEY AMDUR
# 7     3286          LISA GHOTBI
# 8     3358         PEDRO SAPIDA
# 9     3365          LINDA SIMON
# 10    3391       EPHREM NAIZGHI
# 11    3449          BOB PALACIO
# 12    3545  JEFFERY LITTLEFIELD
# 13    3554        KATHLEEN MARK
# 14    3624   HEMALATHA NEKKANTI
# 15    3654   BERNARDITA ARRIETA
# 16    3655       MARIA BARTEAUX
# 17    3707        DAVID ASSMANN
# 18    3862        MICHELLE LONG
# 19    3932         MARK LOZOVOY
# 20    3933           JOHN DAVEY
# 21    3950       THOMAS DISANTO
# 22    3989             SUE WONG
# 23    4100        CRYSTAL CHANG
# 24    4200          ARTHUR WONG
# 25    4290         JEANNIE WONG
# 26    4343      JONATHAN KAPLAN
# 27    4349         HUMPHREY LOE
# 28    4471             CHI WONG
# 29    4474            JEFF PERA
# 30    4500          UMESH GUPTA
# 31    4501   ROBIN CASTIGLIA JR
# 32    4502           JOSE PERLA
# 33    4503         ISABEL VULIS
# 34    4504     FREDY DORSAINVIL
# 35    4506           JOHN MCGEE
# 36    4507      MICHAEL HOFFMAN
# 37    4508          JOE ARMENTA
# 38    4510         JEFFREY BLAU
# 39    4511           DARRYL YEE
# 40    4512    ARIEL DEL ROSARIO
# 41    4513     RODRIGO CASTILLO
# 42    4520     GREGORY WOELFFER
# 43    4521        BRIAN ROBERTS
# 44    4522     GREGORY BRASWELL
# 45    4559            KIM TALLY
# 46    4593        ROSA ESQUIVEL
# 47    4594           FRANK LARA
# 48    4735   MADELEINE LICAVOLI
# 49   44282            Kim Tally
# 50   44893              Fang Lu
# 51   45085      Herman Brown Jr
# 52   46024           Kellee Hom
# 53   46724      Mir Amanath Ali
# 54  122086   Hemalatha Nekkanti
#
#                                             JobTitle    BasePay  OvertimePay  \
# 0                                 DEPUTY DIRECTOR II  138204.53            0
# 1                                DEPUTY DIRECTOR III  146718.76            0
# 2                                DEPUTY DIRECTOR III  138563.65            0
# 3                                 DEPUTY DIRECTOR II  141161.24            0
# 4   DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AG
# 42  San Francisco
# 43  San Francisco
# 44  San Francisco
# 45  San Francisco
# 46  San Francisco
# 47  San Francisco
# 48  San Francisco
# 49  San Francisco
# 50  San Francisco
# 51  San Francisco
# 52  San Francisco
# 53  San Francisco
# 54  San Francisco     PT

# %% [markdown]
# ### ***10. Show All Employees Ordered By Their TotalPay Benefits In Descending Order***

# %%
q="select EmployeeName,TotalPayBenefits from salaries where EmployeeName !='Not provided' order by TotalPayBenefits desc"
sql_query(q)
# Out:
#                 EmployeeName  TotalPayBenefits
# 0             NATHANIEL FORD         567595.43
# 1               GARY JIMENEZ         538909.28
# 2                David Shinn         510732.68
# 3                 Amy P Hart         479652.21
# 4       William J Coaker Jr.         436224.36
# ...                      ...               ...
# 148645         Roy I Tillery              0.00
# 148646      Timothy E Gibson             -2.73
# 148647        Mark E Laherty             -8.20
# 148648         David P Kucia            -33.89
# 148649             Joe Lopez           -618.13
#
# [148650 rows x 2 columns]

# %% [markdown]
# ### ***11. How many employees in the salaries table have OvertimePay equal to 0?***

# %%
q="select * from salaries where OvertimePay = 0"
sql_query(q)
# Out:
#            Id        EmployeeName  \
# 0           1      NATHANIEL FORD
# 1           8       DAVID KUSHNER
# 2          10  JOANNE HAYES-WHITE
# 3          13   EDWARD HARRINGTON
# 4          14         JOHN MARTIN
# ...       ...                 ...
# 77316  148646    Carolyn A Wilson
# 77317  148648      Joann Anderson
# 77318  148649         Leon Walker
# 77319  148650       Roy I Tillery
# 77320  148654           Joe Lopez
#
#                                              JobTitle     BasePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  184152.298
# 1                      DEPUTY DIRECTOR OF INVESTMENTS   256576.96
# 2              CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)      285262
# 3                         EXECUTIVE CONTRACT EMPLOYEE   294580.02
# 4                                   DEPARTMENT HEAD V   271329.03
# ...                                               ...         ...
# 77316                       Human Services Technician           0
# 77317                     Communications Dispatcher 2           0
# 77318                                       Custodian           0
# 77319                                       Custodian           0
# 77320                      Counselor, Log Cabin Ranch           0
#
#        OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0                0  400184.25           567595.43         567595.43  2011
# 1                0   51322.50           307899.46         307899.46  2011
# 2                0   17115.73           302377.73         302377.73  2011
# 3                0       0.00           294580.02         294580.02  2011
# 4                0   21342.59           292671.62         292671.62  2011
# ...            ...        ...      ...        ...               ...   ...
# 77316            0       0.00        0       0.00              0.00  2014
# 77317            0       0.00        0       0.00              0.00  2014
# 77318            0       0.00        0       0.00              0.00  2014
# 77319            0       0.00        0       0.00              0.00  2014
# 77320            0    -618.13        0    -618.13           -618.13  2014
#
#       Notes         Agency Status
# 0            San Francisco
# 1            San Francisco
# 2            San Francisco
# 3            San Francisco
# 4            San Francisco
# ...     ...            ...    ...
# 77316        San Francisco     PT
# 77317        San Francisco     PT
# 77318        San Francisco     PT
# 77319        San Francisco     PT
# 77320        San Francisco     PT
#
# [77321 rows x 13 columns]

# %%
q="select count(*) from salaries where OvertimePay = 0"
sql_query(q)
# Out:
#    count(*)
# 0     77321
